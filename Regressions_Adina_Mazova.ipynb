# %%
import pandas as pd
import statsmodels.api as sm

# %%
con = pd.read_excel('ИЭФ.xls.xlsx')

# %%
X = con[['Exzam1', 'Exzam2', 'Exzam3', 'Exzam4', 'Exzam5', 'Exzam6', 'Exzam7']] #Selected columns
Y = con['SummBall']
X = sm.add_constant(X)

# %%
#Kitchen sink model for OLS Regression Results
ks = sm.OLS(Y, X)
ks_res =ks.fit()
ks_res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               SummBall   R-squared:                       0.991
# Model:                            OLS   Adj. R-squared:                  0.991
# Method:                 Least Squares   F-statistic:                     3434.
# Date:                Mon, 30 Oct 2023   Prob (F-statistic):          2.10e-222
# Time:                        14:42:55   Log-Likelihood:                 134.82
# No. Observations:                 230   AIC:                            -253.6
# Df Residuals:                     222   BIC:                            -226.1
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.1248      0.054     -2.326      0.021      -0.230      -0.019
# Exzam1         0.1379      0.008     16.810      0.000       0.122       0.154
# Exzam2         0.1407      0.009     15.324      0.000       0.123       0.159
# Exzam3         0.1431      0.009     15.872      0.000       0.125       0.161
# Exzam4         0.1447      0.008     18.482      0.000       0.129       0.160
# Exzam5         0.1541      0.007     22.343      0.000       0.141       0.168
# Exzam6         0.1651      0.008     20.935      0.000       0.150       0.181
# Exzam7         0.1266      0.009     14.713      0.000       0.110       0.144
# ==============================================================================
# Omnibus:                        1.585   Durbin-Watson:                   1.904
# Prob(Omnibus):                  0.453   Jarque-Bera (JB):                1.457
# Skew:                           0.195   Prob(JB):                        0.483
# Kurtosis:                       3.009   Cond. No.                         108.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
#Using R-like formulas
import statsmodels.formula.api as smf
ksf =  smf.ols(' SummBall ~ Exzam1 + Exzam2 + Exzam3 + Exzam4 + Exzam5 + Exzam6 + Exzam7 ', data=con)
ksf_res = ksf.fit()
ksf_res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               SummBall   R-squared:                       0.991
# Model:                            OLS   Adj. R-squared:                  0.991
# Method:                 Least Squares   F-statistic:                     3434.
# Date:                Mon, 30 Oct 2023   Prob (F-statistic):          2.10e-222
# Time:                        14:43:54   Log-Likelihood:                 134.82
# No. Observations:                 230   AIC:                            -253.6
# Df Residuals:                     222   BIC:                            -226.1
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.1248      0.054     -2.326      0.021      -0.230      -0.019
# Exzam1         0.1379      0.008     16.810      0.000       0.122       0.154
# Exzam2         0.1407      0.009     15.324      0.000       0.123       0.159
# Exzam3         0.1431      0.009     15.872      0.000       0.125       0.161
# Exzam4         0.1447      0.008     18.482      0.000       0.129       0.160
# Exzam5         0.1541      0.007     22.343      0.000       0.141       0.168
# Exzam6         0.1651      0.008     20.935      0.000       0.150       0.181
# Exzam7         0.1266      0.009     14.713      0.000       0.110       0.144
# ==============================================================================
# Omnibus:                        1.585   Durbin-Watson:                   1.904
# Prob(Omnibus):                  0.453   Jarque-Bera (JB):                1.457
# Skew:                           0.195   Prob(JB):                        0.483
# Kurtosis:                       3.009   Cond. No.                         108.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
#Scatterplot matrix
import seaborn as sns
sns.pairplot(X);

# %%
#Restricting variables in the scatterplot matrix
sns.pairplot(X[['Exzam1', 'Exzam2', 'Exzam3', 'Exzam4', 'Exzam5', 'Exzam6', 'Exzam7']]);

# %%
#Correlation matrix
round(con.corr(),2)
# Out:
# <ipython-input-12-0014acbcd5f4>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   round(con.corr(),2)
#             Unnamed: 0  Unnamed: 1  Pl-B  Exzam1  Exzam2  Exzam3  Exzam4  \
# Unnamed: 0        1.00         NaN -0.31    0.25   -0.08    0.09    0.28
# Unnamed: 1         NaN         NaN   NaN     NaN     NaN     NaN     NaN
# Pl-B             -0.31         NaN  1.00   -0.56   -0.52   -0.47   -0.42
# Exzam1            0.25         NaN -0.56    1.00    0.49    0.53    0.48
# Exzam2           -0.08         NaN -0.52    0.49    1.00    0.73    0.51
# Exzam3            0.09         NaN -0.47    0.53    0.73    1.00    0.57
# Exzam4            0.28         NaN -0.42    0.48    0.51    0.57    1.00
# Exzam5            0.02         NaN -0.41    0.46    0.58    0.56    0.40
# Exzam6           -0.23         NaN -0.36    0.35    0.79    0.65    0.40
# Exzam7            0.01         NaN -0.44    0.49    0.73    0.77    0.46
# Exzam8           -0.03         NaN -0.42    0.49    0.72    0.69    0.53
# Exzam9           -0.21         NaN -0.58    0.72    0.60    0.73    0.51
# SummBall          0.03         NaN -0.56    0.65    0.88    0.87    0.67
# NewVar5            NaN         NaN   NaN     NaN     NaN     NaN     NaN
# Math              0.25         NaN -0.74    0.46    0.60    0.54    0.41
# LangR             0.02         NaN -0.69    0.49    0.63    0.53    0.42
# Foring           -0.01         NaN -0.68    0.45    0.57    0.47    0.31
# TestS             0.09         NaN -0.78    0.52    0.67    0.57    0.42
# Z                 0.09         NaN -0.78    0.52    0.67    0.57    0.42
# TSumma            0.09         NaN -0.78    0.52    0.67    0.57    0.42
# NewVar            0.07         NaN -0.74    0.49    0.64    0.55    0.39
#
#             Exzam5  Exzam6  Exzam7  ...  Exzam9  SummBall  NewVar5  Math  \
# Unnamed: 0    0.02   -0.23    0.01  ...   -0.21      0.03      NaN  0.25
# Unnamed: 1     NaN     NaN     NaN  ...     NaN       NaN      NaN   NaN
# Pl-B         -0.41   -0.36   -0.44  ...   -0.58     -0.56      NaN -0.74
# Exzam1        0.46    0.35    0.49  ...    0.72      0.65      NaN  0.46
# Exzam2        0.58    0.79    0.73  ...    0.60      0.88      NaN  0.60
# Exzam3        0.56    0.65    0.77  ...    0.73      0.87      NaN  0.54
# Exzam4        0.40    0.40    0.46  ...    0.51      0.67      NaN  0.41
# Exzam5        1.00    0.52    0.50  ...    0.69      0.73      NaN  0.51
# Exzam6        0.52    1.00    0.70  ...    0.45      0.83      NaN  0.47
# Exzam7        0.50    0.70    1.00  ...    0.37      0.84      NaN  0.51
# Exzam8        0.63    0.72    0.65  ...    0.68      0.86      NaN  0.49
# Exzam9        0.69    0.45    0.37  ...    1.00      0.72      NaN  0.56
# SummBall      0.73    0.83    0.84  ...    0.72      1.00      NaN  0.63
# NewVar5        NaN     NaN     NaN  ...     NaN       NaN      NaN   NaN
# Math          0.51    0.47    0.51  ...    0.56      0.63      NaN  1.00
# LangR         0.60    0.54    0.50  ...    0.58      0.68      NaN  0.70
# Foring        0.57    0.43    0.46  ...    0.43      0.59      NaN  0.70
# TestS         0.63    0.53    0.55  ...    0.59      0.70      NaN  0.89
# Z             0.63    0.53    0.55  ...    0.59      0.70      NaN  0.89
# TSumma        0.63    0.53    0.55  ...    0.59      0.70      NaN  0.89
# NewVar        0.63    0.51    0.54  ...    0.56      0.68      NaN  0.87
#
#             LangR  Foring  TestS     Z  TSumma  NewVar
# Unnamed: 0   0.02   -0.01   0.09  0.09    0.09    0.07
# Unnamed: 1    NaN     NaN    NaN   NaN     NaN     NaN
# Pl-B        -0.69   -0.68  -0.78 -0.78   -0.78   -0.74
# Exzam1       0.49    0.45   0.52  0.52    0.52    0.49
# Exzam2       0.63    0.57   0.67  0.67    0.67    0.64
# Exzam3       0.53    0.47   0.57  0.57    0.57    0.55
# Exzam4       0.42    0.31   0.42  0.42    0.42    0.39
# Exzam5       0.60    0.57   0.63  0.63    0.63    0.63
# Exzam6       0.54    0.43   0.53  0.53    0.53    0.51
# Exzam7       0.50    0.46   0.55  0.55    0.55    0.54
# Exzam8       0.59    0.47   0.57  0.57    0.57    0.55
# Exzam9       0.58    0.43   0.59  0.59    0.59    0.56
# SummBall     0.68    0.59   0.70  0.70    0.70    0.68
# NewVar5       NaN     NaN    NaN   NaN     NaN     NaN
# Math         0.70    0.70   0.89  0.89    0.89    0.87
# LangR        1.00    0.72   0.90  0.90    0.90    0.89
# Foring       0.72    1.00   0.91  0.91    0.91    0.90
# TestS        0.90    0.91   1.00  1.00    1.00    0.99
# Z            0.90    0.91   1.00  1.00    1.00    0.99
# TSumma       0.90    0.91   1.00  1.00    1.00    0.99
# NewVar       0.89    0.90   0.99  0.99    0.99    1.00
#
# [21 rows x 21 columns]

# %%
#Manual stepwise refinement
X1 = X.drop(columns='Exzam6', inplace=False)
mod1 = sm.OLS(Y, X1)
mod1_res = mod1.fit()
mod1_res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               SummBall   R-squared:                       0.973
# Model:                            OLS   Adj. R-squared:                  0.972
# Method:                 Least Squares   F-statistic:                     1328.
# Date:                Mon, 30 Oct 2023   Prob (F-statistic):          1.85e-171
# Time:                        14:49:55   Log-Likelihood:                 9.4760
# No. Observations:                 230   AIC:                            -4.952
# Df Residuals:                     223   BIC:                             19.11
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0438      0.092     -0.475      0.635      -0.225       0.138
# Exzam1         0.1097      0.014      7.874      0.000       0.082       0.137
# Exzam2         0.2392      0.014     17.643      0.000       0.213       0.266
# Exzam3         0.1546      0.015      9.990      0.000       0.124       0.185
# Exzam4         0.1392      0.013     10.338      0.000       0.113       0.166
# Exzam5         0.1733      0.012     14.729      0.000       0.150       0.196
# Exzam7         0.1698      0.014     11.816      0.000       0.141       0.198
# ==============================================================================
# Omnibus:                        1.889   Durbin-Watson:                   1.857
# Prob(Omnibus):                  0.389   Jarque-Bera (JB):                1.567
# Skew:                          -0.123   Prob(JB):                        0.457
# Kurtosis:                       3.321   Cond. No.                         101.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
#Manual refinement in formula mode without age_25_29
mod1f =  smf.ols(' SummBall ~ Exzam1 + Exzam2 + Exzam3 + Exzam4 + Exzam5 + Exzam6 + Exzam7 ', data=con)
mod1f_res = mod1f.fit()
mod1f_res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               SummBall   R-squared:                       0.991
# Model:                            OLS   Adj. R-squared:                  0.991
# Method:                 Least Squares   F-statistic:                     3434.
# Date:                Mon, 30 Oct 2023   Prob (F-statistic):          2.10e-222
# Time:                        14:50:28   Log-Likelihood:                 134.82
# No. Observations:                 230   AIC:                            -253.6
# Df Residuals:                     222   BIC:                            -226.1
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.1248      0.054     -2.326      0.021      -0.230      -0.019
# Exzam1         0.1379      0.008     16.810      0.000       0.122       0.154
# Exzam2         0.1407      0.009     15.324      0.000       0.123       0.159
# Exzam3         0.1431      0.009     15.872      0.000       0.125       0.161
# Exzam4         0.1447      0.008     18.482      0.000       0.129       0.160
# Exzam5         0.1541      0.007     22.343      0.000       0.141       0.168
# Exzam6         0.1651      0.008     20.935      0.000       0.150       0.181
# Exzam7         0.1266      0.009     14.713      0.000       0.110       0.144
# ==============================================================================
# Omnibus:                        1.585   Durbin-Watson:                   1.904
# Prob(Omnibus):                  0.453   Jarque-Bera (JB):                1.457
# Skew:                           0.195   Prob(JB):                        0.483
# Kurtosis:                       3.009   Cond. No.                         108.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
#Regression diagnostics
from scipy import stats
sns.distplot(mod1_res.resid, fit=stats.norm);
# Out:
# <ipython-input-16-fbaee8ccaca8>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(mod1_res.resid, fit=stats.norm);

# %%
sns.boxplot(mod1_res.resid, showmeans=True);

# %%
sm.qqplot(mod1_res.resid, line='s');

# %%
import matplotlib.pyplot as plt
import numpy as np

Y_max = Y.max()
Y_min = Y.min()

ax = sns.scatterplot(x=mod1_res.fittedvalues, y=Y)
ax.set(ylim=(Y_min, Y_max))
ax.set(xlim=(Y_min, Y_max))
ax.set_xlabel("Predicted value of SummBall")
ax.set_ylabel("Observed value of SummBall")

X_ref = Y_ref = np.linspace(Y_min, Y_max, 100)
plt.plot(X_ref, Y_ref, color='red', linewidth=1)
plt.show()

# %%
#Creating standardized input matrices
from scipy import stats
Y_norm = pd.Series(stats.zscore(Y), name=Y.name)
Y_norm.head(3)
# Out:
# 0    1.320187
# 1    1.320187
# 2    0.432082
# Name: SummBall, dtype: float64

# %%
X1_norm = X1.loc[:, X1.columns != "const"]
X1_norm = pd.DataFrame(stats.zscore(X1_norm))
X1_norm = sm.add_constant(X1_norm)
X1_norm.columns = X1.columns
check = pd.concat([round(X1_norm.mean(axis=0), 5), round(X1_norm.std(axis=0, ddof=0), 5)], axis=1)
check.columns=["mean", "std dev"]
check
# Out:
#         mean  std dev
# const    1.0      0.0
# Exzam1   0.0      1.0
# Exzam2  -0.0      1.0
# Exzam3   0.0      1.0
# Exzam4  -0.0      1.0
# Exzam5   0.0      1.0
# Exzam7  -0.0      1.0

# %%
#Running the standardized regression
modstd = sm.OLS(Y_norm, X1_norm)
modstd_res = modstd.fit()
modstd_res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               SummBall   R-squared:                       0.973
# Model:                            OLS   Adj. R-squared:                  0.972
# Method:                 Least Squares   F-statistic:                     1328.
# Date:                Mon, 30 Oct 2023   Prob (F-statistic):          1.85e-171
# Time:                        14:52:36   Log-Likelihood:                 88.092
# No. Observations:                 230   AIC:                            -162.2
# Df Residuals:                     223   BIC:                            -138.1
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -2.515e-17      0.011  -2.28e-15      1.000      -0.022       0.022
# Exzam1         0.1096      0.014      7.874      0.000       0.082       0.137
# Exzam2         0.3243      0.018     17.643      0.000       0.288       0.361
# Exzam3         0.2015      0.020      9.990      0.000       0.162       0.241
# Exzam4         0.1451      0.014     10.338      0.000       0.117       0.173
# Exzam5         0.2095      0.014     14.729      0.000       0.181       0.238
# Exzam7         0.2252      0.019     11.816      0.000       0.188       0.263
# ==============================================================================
# Omnibus:                        1.889   Durbin-Watson:                   1.857
# Prob(Omnibus):                  0.389   Jarque-Bera (JB):                1.567
# Skew:                          -0.123   Prob(JB):                        0.457
# Kurtosis:                       3.321   Cond. No.                         4.27
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
#Tornado diagram
coeff = modstd_res.params
coeff = coeff.iloc[(coeff.abs()*-1.0).argsort()]
sns.barplot(x=coeff.values, y=coeff.index, orient='h');

# %%
#Create a sklearn kitchen sink mode
X2 = X
X2.drop("const", axis=1, inplace=True)
X2.head(3)
# Out:
#    Exzam1  Exzam2  Exzam3  Exzam4  Exzam5  Exzam6  Exzam7
# 0       7       9       8       7       8      10      10
# 1       6       9      10       6      10       8       9
# 2       5       6       7       7       9       9      10

# %%
from sklearn.linear_model import LinearRegression
from mlxtend.feature_selection import SequentialFeatureSelector as SFS
from mlxtend.plotting import plot_sequential_feature_selection as plot_sfs

# %%
mod = LinearRegression()
mod.fit(X2,Y)
# Out:
# LinearRegression()

# %%
coef = pd.concat([pd.Series(X2.columns), pd.Series(mod.coef_)], axis=1)
coef.columns=["variable", "coefficient"]
coef
# Out:
#   variable  coefficient
# 0   Exzam1     0.137941
# 1   Exzam2     0.140665
# 2   Exzam3     0.143051
# 3   Exzam4     0.144663
# 4   Exzam5     0.154142
# 5   Exzam6     0.165071
# 6   Exzam7     0.126558

# %%
#Running the refinement algorithm
sfs = SFS(mod,
         k_features='best',
         forward=False,
         floating=False,
         scoring='r2',
         cv=30)

sfs = sfs.fit(X2,Y)

# %%
#Viewing the iterations
pd.DataFrame.from_dict(sfs.get_metric_dict(confidence_interval=0.95)).T
# Out:
#              feature_idx                                          cv_scores  \
# 7  (0, 1, 2, 3, 4, 5, 6)  [0.9839563251363942, 0.995531637303064, 0.9916...
# 6     (0, 1, 2, 3, 4, 5)  [0.9851667841099532, 0.9872240705891677, 0.970...
# 5        (0, 1, 2, 4, 5)  [0.9864415589993131, 0.9644106822700382, 0.962...
# 4           (0, 1, 2, 5)  [0.9786536700349053, 0.9361937218867498, 0.921...
# 3              (0, 2, 5)  [0.9606092813419838, 0.9019436429145231, 0.941...
# 2                 (2, 5)  [0.940527139409169, 0.9091168203136784, 0.8819...
# 1                   (2,)  [0.7261751848807677, 0.8720225489083215, 0.825...
#
#   avg_score                                      feature_names  ci_bound  \
# 7  0.983522  (Exzam1, Exzam2, Exzam3, Exzam4, Exzam5, Exzam...  0.004635
# 6  0.967514   (Exzam1, Exzam2, Exzam3, Exzam4, Exzam5, Exzam6)  0.010569
# 5  0.947127           (Exzam1, Exzam2, Exzam3, Exzam5, Exzam6)  0.015122
# 4  0.915854                   (Exzam1, Exzam2, Exzam3, Exzam6)  0.023984
# 3  0.872098                           (Exzam1, Exzam3, Exzam6)   0.04748
# 2  0.792435                                   (Exzam3, Exzam6)  0.073437
# 1  0.608875                                          (Exzam3,)  0.120451
#
#     std_dev   std_err
# 7  0.012223   0.00227
# 6  0.027869  0.005175
# 5  0.039875  0.007405
# 4  0.063242  0.011744
# 3  0.125198  0.023249
# 2  0.193642  0.035958
# 1  0.317611  0.058979

# %%
#Picking the best model visually
plot_sfs(sfs.get_metric_dict(), kind='std_err')
plt.grid()
plt.show()

# %%
#Viewing the best model
sfs.subsets_[7].get('feature_names')
# Out:
# ('Exzam1', 'Exzam2', 'Exzam3', 'Exzam4', 'Exzam5', 'Exzam6', 'Exzam7')
